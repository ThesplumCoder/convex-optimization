# %% [markdown]
# # Redes Neuronales con Gradiente Descendiente Estocástico

# %% [markdown]
# ## Configuración del entorno

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install scipy
# Out:
# Requirement already satisfied: numpy in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (2.2.5)
# Requirement already satisfied: matplotlib in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from matplotlib) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: scipy in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (1.15.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /home/anderson/Documentos/Github/convex-optimization/venv/lib/python3.11/site-packages (from scipy) (2.2.5)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %% [markdown]
# ## Definición del Gradiente Descendiente Estocástico

# %% [markdown]
# El método de gradiente descendiente podemos modelarlo así:
#
# $$
# \theta^{k + 1} = \theta^k - \alpha \nabla L(f_\theta(X), Y)
# $$
#
# Los parámetros para optimizar son:
# + $\alpha \leftarrow$ learning rate.
# + $k \leftarrow$ iteraciones (epochs).
# + $f_\theta \leftarrow$ capas. Aquí se pueden aumentar capas o neuronas.
#
# Para el método **Gradiente Descendiente Estocástico** lo que tenemos que hacer es separar nuestros datos por bloques, a esto lo llamaremos *batches*. Cuando se entrene y se recorran todos los bloques (todos los datos) entonces se habrá hecho una época o *epoch*.

# %% [markdown]
# ## Implementación de la red

# %% [markdown]
# Definimos un conjunto de funciones comunes que nos ayudaran para la construcción de la red y para evaluarla.

# %%
def relu(Z):
    return np.maximum(0, Z)

def sigmoid(Z):
    return 1 / (1 + np.exp(-Z))


def logistic_cost(Y_hat, Y):
    m = Y.shape[1]
    cost = -np.sum(Y * np.log(Y_hat + 1e-8) + (1 - Y) * np.log(1 - Y_hat + 1e-8)) / m
    return cost


def prediction(X, Y, b, W):
    A = X
    for i in range(len(W) - 1):
        Z = W[i] @ A + b[i]
        A = relu(Z)
    Z = W[-1] @ A + b[-1]
    Y_hat = sigmoid(Z)
    preds = Y_hat > 0.5
    acc = np.mean(preds == Y)
    print(f"Accuracy: {acc*100:.2f}%")

# %% [markdown]
# Cargamos los datos y los visualizamos.

# %%
# Load MATLAB data
data = loadmat('../../resources/data/neural-networks/data.mat')

X = data['X'].T
Y = data['y'].T
x_test = data['Xval'].T
y_test = data['yval'].T

# Plot the dataset
plt.figure()
plt.scatter(X[0, Y[0] == 0], X[1, Y[0] == 0], c='red', label='Class 0')
plt.scatter(X[0, Y[0] == 1], X[1, Y[0] == 1], c='blue', label='Class 1')
plt.legend()
plt.title("Training Data")
plt.show()

# %% [markdown]
# Definimos la red neuronal, aquí está presente la inicialización de los pesos $W$, el *forward* y el *backward*. Para calcular las iteraciones de gradiente descendiente en el estocástico, debemos hacer lo siguiente:
#
# $$
# iters = epochs * \lceil \frac{data\ size}{batch} \rceil
# $$

# %%
print(np.ceil(211 / 16).astype(int))
print(11000 / np.ceil(211 / 16).astype(int))
# Out:
# 14
# 785.7142857142857

# %%
# Define dimensions
m, L = X.shape
c = Y.shape[0]
layers_dims = [m, 10, 3, c]

# Initialization
W = []
b = []
for i in range(1, len(layers_dims)):
    W.append(np.random.randn(layers_dims[i], layers_dims[i-1]) / np.sqrt(layers_dims[i-1]))
    b.append(np.zeros((layers_dims[i], 1)))

learning_rate = 0.5
# The target iterations is 11000.
epochs = 100
batch_size = 16
cost = []

def gradient_iters(data_size, batch):
    return np.ceil(data_size / batch).astype(int)

# Training Loop
for epoch in range(epochs):
    indexes = np.arange(0, L, 1)
    rng = np.random.default_rng()
    rng.shuffle(indexes)
    X = X[:, indexes]
    Y = Y[:, indexes]
    
    for batch_index in range(gradient_iters(L, batch_size)):
        lower_lim = batch_index * batch_size
        upper_lim = batch_index * batch_size + batch_size
        X_batch = X[:, lower_lim:upper_lim]
        Y_batch = Y[:, lower_lim:upper_lim]
        
        # Forward propagation
        Z1 = W[0] @ X_batch + b[0]
        A1 = relu(Z1)
        Z2 = W[1] @ A1 + b[1]
        A2 = relu(Z2)
        Z3 = W[2] @ A2 + b[2]
        A3 = sigmoid(Z3)
        cost.append(logistic_cost(A3, Y_batch))
    
        # Backpropagation
        dZ3 = A3 - Y_batch
        dW3 = (1/L) * (dZ3 @ A2.T)
        db3 = (1/L) * np.sum(dZ3, axis=1, keepdims=True)
    
        dA2 = W[2].T @ dZ3
        dZ2 = dA2 * (A2 > 0)
        dW2 = (1/L) * (dZ2 @ A1.T)
        db2 = (1/L) * np.sum(dZ2, axis=1, keepdims=True)
    
        dA1 = W[1].T @ dZ2
        dZ1 = dA1 * (A1 > 0)
        dW1 = (1/L) * (dZ1 @ X_batch.T)
        db1 = (1/L) * np.sum(dZ1, axis=1, keepdims=True)
    
        # Update weights
        W[0] -= learning_rate * dW1
        b[0] -= learning_rate * db1
        W[1] -= learning_rate * dW2
        b[1] -= learning_rate * db2
        W[2] -= learning_rate * dW3
        b[2] -= learning_rate * db3

# %% [markdown]
# Graficamos el resultado de las predicciones de la red.

# %%
# Final prediction
print("Performance for training data")
prediction(X, Y, b, W)

print("\nPerformance for testing data")
prediction(x_test, y_test, b, W)

plt.plot(cost)
plt.xlabel("steps (gradient descent)")
plt.ylabel("cost")
plt.show()
# Out:
# Performance for training data
# Accuracy: 92.89%
#
# Performance for testing data
# Accuracy: 93.50%
